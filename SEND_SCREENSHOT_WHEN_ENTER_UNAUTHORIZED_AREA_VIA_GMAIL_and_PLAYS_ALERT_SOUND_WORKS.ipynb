# %%
pip install playsound
# Out:
# Collecting playsound
#   Downloading playsound-1.3.0.tar.gz (7.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: playsound
#   Building wheel for playsound (setup.py): started
#   Building wheel for playsound (setup.py): finished with status 'done'
#   Created wheel for playsound: filename=playsound-1.3.0-py3-none-any.whl size=7043 sha256=c16f2c8bb979ef1195872ff602c4af7920400cd05307772d561468a82aab1406
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\cf\42\ff\7c587bae55eec67b909ca316b250d9b4daedbf272a3cbeb907
# Successfully built playsound
# Installing collected packages: playsound
# Successfully installed playsound-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install pywhatkit

# %%
import pywhatkit as kit

def send_whatsapp_message():
    # Replace with the phone number you want to send the message to
    phone_number = "+919060804108"  # Include the country code
    message = "Hello, this is a test message sent from Python!"

    # Schedule the message to be sent in the next minute
    kit.sendwhatmsg(phone_number, message, hour=16, minute=12)

# %%
import cv2
import numpy as np
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders
from ultralytics import YOLO
import time
from playsound import playsound
#from twilio.rest import Client

# Load YOLOv8 model
model = YOLO('yolov8n.pt')

# Email configuration
def send_email_alert(image_path):
    sender_email = 'behappy20041@gmail.com'
    receiver_email = 'kunal.jcdu@gmail.com'
    password = 'syaa ryxd eqpk zixz'
    
    subject = "Alert: Restricted Area Breach Detected"
    body = "Someone has crossed the restricted area."

    msg = MIMEMultipart()
    msg['From'] = sender_email
    msg['To'] = receiver_email
    msg['Subject'] = subject

    msg.attach(MIMEText(body, 'plain'))

    # Attach the screenshot
    attachment = open(image_path, "rb")
    part = MIMEBase('application', 'octet-stream')
    part.set_payload((attachment).read())
    encoders.encode_base64(part)
    part.add_header('Content-Disposition', f"attachment; filename= {image_path}")
    msg.attach(part)

    try:
        server = smtplib.SMTP('smtp.gmail.com', 587)
        server.starttls()
        server.login(sender_email, password)
        text = msg.as_string()
        server.sendmail(sender_email, receiver_email, text)
        server.quit()
        print("Email with screenshot sent successfully.")
    except Exception as e:
        print(f"Failed to send email: {e}")

# WhatsApp configuration using Twilio
#def send_whatsapp_alert():
 #   account_sid = 'your_account_sid'
  #  auth_token = 'your_auth_token'
   # client = Client(account_sid, auth_token)
#
 #   message = client.messages.create(
  #      body="Alert: Someone has crossed the restricted area!",
   #     from_='whatsapp:+14155238886',  # Twilio's WhatsApp sandbox number
    #    to='whatsapp:+your_whatsapp_number'
    #)

    #print(f"WhatsApp message sent: {message.sid}")

# Define the restricted area rectangle
RECTANGLE_START = (100, 200)  # Top-left corner of the rectangle (x, y)
RECTANGLE_END = (500, 400)    # Bottom-right corner of the rectangle (x, y)

# Initialize the video capture
cap = cv2.VideoCapture(0)

# Timing setup
last_sent_time = 0
interval = 30  # 30 seconds interval

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Perform detection
    results = model(frame)

    # Draw the restricted area rectangle
    cv2.rectangle(frame, RECTANGLE_START, RECTANGLE_END, (0, 0, 255), 2)

    for result in results:
        boxes = result.boxes
        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])

            # Check if the detected object is a person
            if int(box.cls[0]) == 0:  # Class 0 is 'person' in COCO dataset
                # Draw bounding box
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

                # Check if the person has crossed the rectangle
                if (x2 > RECTANGLE_START[0] and x1 < RECTANGLE_END[0] and
                    y2 > RECTANGLE_START[1] and y1 < RECTANGLE_END[1]):
                    current_time = time.time()
                    if current_time - last_sent_time > interval:
                        # Save the frame as an image
                        image_path = "breach.png"
                        cv2.imwrite(image_path, frame)

                        # Send alerts
                        send_email_alert(image_path)
                        #send_whatsapp_message()
                        playsound(r'E:\new_downloads_default_folder\siren-alert-96052.wav')  # Play alert sound

                        last_sent_time = current_time

    cv2.imshow("Restricted Area Surveillance", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 256.2ms
# Speed: 8.3ms preprocess, 256.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 255.2ms
# Speed: 8.1ms preprocess, 255.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 243.1ms
# Speed: 6.2ms preprocess, 243.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 249.0ms
# Speed: 7.7ms preprocess, 249.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 252.6ms
# Speed: 5.5ms preprocess, 252.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 247.1ms
# Speed: 8.8ms preprocess, 247.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 252.0ms
# Speed: 5.0ms preprocess, 252.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 256.1ms
# Speed: 6.7ms preprocess, 256.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 256.8ms
# Speed: 6.0ms preprocess, 256.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 239.1ms
# Speed: 4.8ms preprocess, 239.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 250.9ms
# Speed: 6.9ms preprocess, 250.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 451.8ms
# Speed: 5.9ms preprocess, 451.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 380.8ms
# Speed: 5.7ms preprocess, 380.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 334.7ms
# Speed: 4.0ms preprocess, 334.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 384.0ms
# Speed: 5.0ms preprocess, 384.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 313.3ms
# Speed: 6.0ms preprocess, 313.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 321.9ms
# Speed: 5.9ms preprocess, 321.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 295.9ms
# Speed: 5.0ms preprocess, 295.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 315.5ms
# Speed: 5.0ms preprocess, 315.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 293.8ms
# Speed: 5.0ms preprocess, 293.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 313.7ms
# Speed: 4.9ms preprocess, 313.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 299.8ms
# Speed: 4.0ms preprocess, 299.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 307.8ms
# Speed: 6.0ms preprocess, 307.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 314.6ms
# Speed: 6.0ms preprocess, 314.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 294.2ms
# Speed: 4.0ms preprocess, 294.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 287.1ms
# Speed: 4.0ms preprocess, 287.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 291.5ms
# Speed: 5.0ms preprocess, 291.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 316.5ms
# Speed: 6.9ms preprocess, 316.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 289.7ms
# Speed: 3.8ms preprocess, 289.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 297.1ms
# Speed: 5.0ms preprocess, 297.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 287.1ms
# Speed: 6.0ms preprocess, 287.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 280.3ms
# Speed: 8.5ms preprocess, 280.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 345.1ms
# Speed: 5.3ms preprocess, 345.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 345.2ms
# Speed: 6.1ms preprocess, 345.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 313.0ms
# Speed: 6.0ms preprocess, 313.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 307.1ms
# Speed: 6.0ms preprocess, 307.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 317.7ms
# Speed: 7.4ms preprocess, 317.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 307.9ms
# Speed: 4.9ms preprocess, 307.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 295.1ms
# Speed: 6.5ms preprocess, 295.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 295.0ms
# Speed: 5.6ms preprocess, 295.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 303.7ms
# Speed: 9.1ms preprocess, 303.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 292.1ms
# Speed: 4.9ms preprocess, 292.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 297.6ms
# Speed: 5.9ms preprocess, 297.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 338.2ms
# Speed: 5.1ms preprocess, 338.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 307.4ms
# Speed: 6.0ms preprocess, 307.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 310.9ms
# Speed: 5.3ms preprocess, 310.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 295.6ms
# Speed: 6.5ms preprocess, 295.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 314.0ms
# Speed: 8.0ms preprocess, 314.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 280.1ms
# Speed: 5.3ms preprocess, 280.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 388.8ms
# Speed: 5.0ms preprocess, 388.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 256.0ms
# Speed: 6.0ms preprocess, 256.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 233.1ms
# Speed: 5.0ms preprocess, 233.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 233.3ms
# Speed: 6.0ms preprocess, 233.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 241.7ms
# Speed: 4.8ms preprocess, 241.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 237.7ms
# Speed: 5.4ms preprocess, 237.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 252.1ms
# Speed: 6.0ms preprocess, 252.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 248.4ms
# Speed: 5.0ms preprocess, 248.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 245.0ms
# Speed: 5.0ms preprocess, 245.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 243.8ms
# Speed: 4.0ms preprocess, 243.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 244.4ms
# Speed: 4.0ms preprocess, 244.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 245.7ms
# Speed: 5.0ms preprocess, 245.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 240.7ms
# Speed: 4.8ms preprocess, 240.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 251.8ms
# Speed: 4.5ms preprocess, 251.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 244.5ms
# Speed: 5.0ms preprocess, 244.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 247.2ms
# Speed: 5.2ms preprocess, 247.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 250.6ms
# Speed: 5.0ms preprocess, 250.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 242.4ms
# Speed: 4.6ms preprocess, 242.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 246.7ms
# Speed: 5.0ms preprocess, 246.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 252.7ms
# Speed: 6.3ms preprocess, 252.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 246.2ms
# Speed: 6.0ms preprocess, 246.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 248.9ms
# Speed: 4.5ms preprocess, 248.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 250.9ms
# Speed: 4.6ms preprocess, 250.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 245.1ms
# Speed: 3.5ms preprocess, 245.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 241.0ms
# Speed: 5.1ms preprocess, 241.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 241.3ms
# Speed: 5.4ms preprocess, 241.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Email with screenshot sent successfully.
#
# 0: 480x640 1 person, 247.0ms
# Speed: 5.0ms preprocess, 247.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 243.3ms
# Speed: 5.1ms preprocess, 243.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 252.8ms
# Speed: 4.0ms preprocess, 252.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 244.7ms
# Speed: 5.0ms preprocess, 244.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 252.3ms
# Speed: 5.0ms preprocess, 252.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 245.2ms
# Speed: 4.0ms preprocess, 245.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 244.3ms
# Speed: 5.0ms preprocess, 244.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 241.5ms
# Speed: 6.0ms preprocess, 241.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 246.2ms
# Speed: 4.0ms preprocess, 246.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 250.1ms
# Speed: 4.0ms preprocess, 250.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 241.9ms
# Speed: 5.0ms preprocess, 241.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 241.9ms
# Speed: 5.2ms preprocess, 241.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 251.5ms
# Speed: 3.8ms preprocess, 251.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 255.9ms
# Speed: 3.8ms preprocess, 255.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 248.7ms
# Speed: 5.0ms preprocess, 248.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 247.3ms
# Speed: 5.6ms preprocess, 247.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 247.9ms
# Speed: 3.9ms preprocess, 247.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 248.2ms
# Speed: 5.0ms preprocess, 248.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 253.8ms
# Speed: 6.0ms preprocess, 253.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 258.1ms
# Speed: 5.0ms preprocess, 258.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 245.1ms
# Speed: 5.0ms preprocess, 245.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 252.8ms
# Speed: 5.0ms preprocess, 252.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 396.9ms
# Speed: 5.0ms preprocess, 396.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 252.7ms
# Speed: 3.0ms preprocess, 252.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 247.4ms
# Speed: 4.0ms preprocess, 247.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 241.6ms
# Speed: 5.0ms preprocess, 241.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 257.4ms
# Speed: 4.5ms preprocess, 257.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 244.7ms
# Speed: 4.0ms preprocess, 244.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 308.3ms
# Speed: 4.8ms preprocess, 308.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 246.9ms
# Speed: 4.0ms preprocess, 246.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 238.5ms
# Speed: 7.0ms preprocess, 238.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 267.6ms
# Speed: 5.0ms preprocess, 267.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 241.8ms
# Speed: 6.0ms preprocess, 241.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 247.9ms
# Speed: 6.0ms preprocess, 247.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 248.2ms
# Speed: 5.0ms preprocess, 248.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 240.0ms
# Speed: 3.9ms preprocess, 240.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 250.5ms
# Speed: 5.0ms preprocess, 250.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 243.2ms
# Speed: 4.9ms preprocess, 243.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 253.2ms
# Speed: 5.0ms preprocess, 253.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 254.6ms
# Speed: 5.0ms preprocess, 254.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 255.9ms
# Speed: 5.0ms preprocess, 255.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 250.0ms
# Speed: 5.1ms preprocess, 250.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 252.7ms
# Speed: 5.0ms preprocess, 252.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 250.3ms
# Speed: 5.5ms preprocess, 250.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 246.0ms
# Speed: 5.0ms preprocess, 246.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 252.1ms
# Speed: 4.0ms preprocess, 252.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 246.4ms
# Speed: 4.0ms preprocess, 246.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 253.2ms
# Speed: 5.4ms preprocess, 253.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 245.0ms
# Speed: 5.0ms preprocess, 245.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 250.3ms
# Speed: 5.0ms preprocess, 250.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 244.9ms
# Speed: 5.2ms preprocess, 244.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 242.2ms
# Speed: 5.0ms preprocess, 242.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 241.2ms
# Speed: 5.0ms preprocess, 241.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 244.2ms
# Speed: 4.0ms preprocess, 244.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 244.3ms
# Speed: 5.3ms preprocess, 244.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 252.6ms
# Speed: 5.0ms preprocess, 252.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 240.6ms
# Speed: 6.1ms preprocess, 240.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 247.0ms
# Speed: 4.0ms preprocess, 247.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 248.9ms
# Speed: 4.0ms preprocess, 248.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Email with screenshot sent successfully.
